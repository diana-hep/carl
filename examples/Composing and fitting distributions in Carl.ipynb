# %% [markdown]
# # Composing and fitting distributions in Carl
#
# Gilles Louppe, January 2016.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import theano
import theano.tensor as T

# %% [markdown]
# ## Base API

# %%
from carl.distributions import Normal
p = Normal(mu=1.0, sigma=2.0)

# %%
reals = np.linspace(-5, 5, num=1000)
plt.plot(reals, p.pdf(reals.reshape(-1, 1)), label="pdf(x)")
plt.legend(loc="best")

# %%
reals = np.linspace(-5, 5, num=1000)
plt.plot(reals, p.nnlf(reals.reshape(-1, 1)), label="-log(pdf(x))")
plt.legend(loc="best")

# %%
reals = np.linspace(-5, 5, num=1000)
plt.plot(reals, p.cdf(reals.reshape(-1, 1)), label="cdf(x)")
plt.legend(loc="best")

# %%
reals = np.linspace(0, 1, num=1000)
plt.plot(reals, p.ppf(reals.reshape(-1, 1)), label="ppf(x)")
plt.legend(loc="best")

# %%
p.rvs(n_samples=10000)
# Out:
# array([[ 1.73985784],
#        [ 0.48909388],
#        [ 2.28507292],
#        ...,
#        [ 0.19060949],
#        [ 3.27413312],
#        [-0.55303698]])

# %% [markdown]
# ## Advanced API

# %%
from carl.distributions import Normal
p = Normal(mu=1.0, sigma=2.0)

# %%
p.parameters_
# Out:
# {sigma, mu}

# %%
p.constants_
# Out:
# set()

# %%
p.observeds_
# Out:
# set()

# %%
a = theano.shared(1.0, name="a")
b = theano.shared(2.0, name="b")
c = T.constant(0.5, name="c")
p = Normal(mu=a * c, sigma=a + b)

# %%
p.mu
# Out:
# Elemwise{mul,no_inplace}.0

# %%
p.mu.eval()
# Out:
# array(0.5)

# %%
p.parameters_
# Out:
# {b, a}

# %%
p.constants_
# Out:
# {TensorConstant{0.5}}

# %%
p.observeds_
# Out:
# set()

# %%
a = T.dmatrix(name="a")
b = theano.shared(1.0, name="b")
c = theano.shared(0.0, name="c")
p = Normal(mu=a*b + c)

# %%
p.parameters_
# Out:
# {sigma, b, c}

# %%
p.constants_
# Out:
# set()

# %%
p.observeds_
# Out:
# {a}

# %%
reals = np.linspace(-5, 5, num=1000)
plt.plot(reals, p.pdf(X=reals.reshape(-1, 1)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-724073d94a63> in <module>()
#       1 reals = np.linspace(-5, 5, num=1000)
# ----> 2 plt.plot(reals, p.pdf(X=reals.reshape(-1, 1)))
#
# /home/gilles/anaconda3/envs/carl/lib/python3.5/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     579                     raise TypeError("Missing required input: %s" %
#     580                                     getattr(self.inv_finder[c], 'variable',
# --> 581                                             self.inv_finder[c]))
#     582                 if c.provided > 1:
#     583                     raise TypeError("Multiple values for input: %s" %
#
# TypeError: Missing required input: a

# %%
plt.plot(reals, p.pdf(X=reals.reshape(-1, 1), 
                      a=np.ones(len(reals)).reshape(-1, 1)), label="pdf(x, a)")
plt.legend()

# %% [markdown]
# ## Composing mixtures

# %%
from carl.distributions import Mixture

components = [
    Normal(mu=-2.0, sigma=0.75),   # c0
    Normal(mu=0.0, sigma=2.0),     # c1
    Normal(mu=1.0, sigma=0.5)      # c2 (bump)
]

g = theano.shared(0.05, name="g") 
p = Mixture(components=components, weights=[0.5 - g / 2., 0.5 - g / 2., g])

# %%
reals = np.linspace(-5, 5, num=1000)
plt.plot(reals, p.pdf(reals.reshape(-1, 1)), label="pdf(x)")
plt.legend()

# %%
p.weights
# Out:
# [Elemwise{true_div,no_inplace}.0,
#  Elemwise{true_div,no_inplace}.0,
#  Elemwise{true_div,no_inplace}.0]

# %%
p.compute_weights()
# Out:
# array([ 0.475,  0.475,  0.05 ])

# %% [markdown]
# ## Fitting parameters to data

# %%
p0 = Normal(mu=1.0, sigma=1.37)
p1 = Normal()
X = p0.rvs(10000)
p1.fit(X, bounds=[{"param": p1.sigma, "bounds": (0, None)}])
# Out:
# Normal(mu=mu, random_state=None, sigma=sigma)

# %%
p1.mu.eval(), p1.sigma.eval()
# Out:
# (array(0.9952224045749574), array(1.3667072523801544))

# %%
reals = np.linspace(-5, 5, num=1000)
plt.hist(X.ravel(), bins=100, normed=1, alpha=0.5, label="x~p0")
plt.plot(reals, p1.pdf(reals.reshape(-1, 1)), label="p1(x)")
plt.legend()
